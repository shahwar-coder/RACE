# %% [markdown]
# ## **1. Python (some poins to know)**
# - Used for Web Development, Software Development, System Scripting, Mathematics
# - Works on different platforms (any OS)
# - Works on an Interpreter System (as soon as code is written it can be executed, prototyping can be quick)
# - Enligh language type and requires fewer lines than other programming languages (easy for developers)

# %% [markdown]
# ## **2. Getting Started**

# %% [markdown]
# 1. Check Python Version

# %%
# python --version

# %% [markdown]
# - After running `python --version` -> you get to see python version installed.
# - This is run in Terminal (mac)
# ![Screenshot 2025-10-24 at 11.21.26 AM.png](data:image/png;base64,...)

# %% [markdown]
# 2. Check System Version

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# ## **3. Python Syntax**

# %% [markdown]
# 1. Simple Printing

# %%
# Printing
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2. Python Indentation

# %%
if True:
  print("Condition is True")

# if condition (Here True) -> then -> execute the statement henceforth if the condition is true
# Out:
# Condition is True

# %%
if 5>2:
  print("Yes 5 is greater than 2.")

# if condition -> then -> execute the statement henceforth if the condition is true
# Out:
# Yes 5 is greater than 2.

# %% [markdown]
# 3. Indentation (no spaces)

# %%
if 5>2:
print("5>2")

# Spaces 0 : Won't work
# Having no spaces at all is improper indentation
# Out:
#   File "/tmp/ipython-input-1808779251.py", line 2
#     print("5>2")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# 4. Indentation (1->4 Spaces)

# %%
if 5>2:
 print("5 is greater than 2.")

# Spaces 1 : Works
# Out:
# 5 is greater than 2.

# %%
if 5>2:
  print("5 is greater than 2.")

# Spaces 2 : Works
# Out:
# 5 is greater than 2.

# %%
if 5>2:
   print("5 is greater than 2.")

# Spaces 3 : Works
# Out:
# 5 is greater than 2.

# %%
if 5>2:
    print("5 is greater than 2.")

# Spaces 4 : Works
# Out:
# 5 is greater than 2.

# %%
# So in conclusion we can say, multiple spaces can preceed the main statement in the block.
# It can be 1, 2, 3, 4, 5, 6, ........n

# %% [markdown]
# 4. Indentation (Proper and then Improper)

# %%
if 5>2:
  print("1: 5 is more than 2")
     print("2: 5 is more than 2")

# Here we first normally have intended print statement (we expect it to work fine).
# But soon after there improper indentation for second print statement.
# Intuitively we think 1st print will work good and print just fine, and from 2nd print we will stat having issues.
# BUT : Python checks indentation strictly — not line-by-line, but block-by-block.
# So eventually we do not have any print (only error)
# Out:
#   File "/tmp/ipython-input-1242711565.py", line 3
#     print("2: 5 is more than 2")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# 5. Indentation (many spaces before statement)

# %%
if 5>2:
                print("5>2")
                print("5>2")

# Every statement in the block should have same spaces before if we consider multiple spaces.
# Out:
# 5>2
# 5>2

# %%
if 5>2:
                print("5>2")
              print("5>2")

# Every statement in the block should have same spaces before if we consider multiple spaces.
# It will give error if we do not have both statements here with same amount of preceeding spaces
# That's just how syntax in Python works
# It's like you cannot do any impartiality with any of the statement in the block.
# Out:
#   File "<tokenize>", line 3
#     print("5>2")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ## **4. Python Statements**

# %% [markdown]
# 1. Simple Statement

# %%
print("My name is Shahwar Alam Naqvi")

# This print statement is a simple statement (a part of program)
# Program = Set of Instructions
# Statement = 1 Instruction
# Statements/Instructions combined = Computer Program
# Out:
# My name is Shahwar Alam Naqvi

# %%
print    ("Hello")

# Spaces between 'print' and '()', does not matter, it still works.
# A small observation, a nuance in python synta (very interesting)
# Out:
# Hello

# %% [markdown]
# 2. Semi Colon is Optional

# %%
print("My name is Shahwar Alam Naqvi")
print("My name is SHAHWAR ALAM NAQVI");

# We do not require semi colon to end any statement in Python
# It is completely optional and is conventionally not used.
# Here you can see that both kinds of statements work fine, one with semi colon and one without it.
# Out:
# My name is Shahwar Alam Naqvi
# My name is SHAHWAR ALAM NAQVI

# %% [markdown]
# 3. Many Statements and Execuion Order

# %%
print("Shahwar")
print("Alam")
print("Naqvi")

# We can have multiple statements
# And the statements execute in order
# Out:
# Shahwar
# Alam
# Naqvi

# %% [markdown]
# 4. Where can this semi colon be mandatory ? Can you think of any such scenario ?

# %%
print("Shahwar") ; print("Alam") ; print("Naqvi")

# This scenario demands use of semi colon between the statements
# The scenario is having multiple statements in ONE line
# Out:
# Shahwar
# Alam
# Naqvi

# %%
print("Shahwar") print("Alam") print("Naqvi")

# Not giving semi colon will yield error
# Out:
#   File "/tmp/ipython-input-2921840230.py", line 1
#     print("Shahwar") print("Alam") print("Naqvi")
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## **5. Python Output**

# %% [markdown]
# 1. Double Quotes and Single Quotes

# %%
x = "your name"
y = 'your name'

print(x)
print(y)
print(x==y)
# Out:
# your name
# your name
# True

# %%
# The following will be errory,
# There is one double quoate and another single
# We need to use pair of either double quotes or single quotes not a mix of two.

print("Shahwar Alam Naqvi') # here I deliberately put incompatible pair of quaotes, 1 is double quote or 1 is single quote.
# Out:
#   File "/tmp/ipython-input-4228351097.py", line 5
#     print("Shahwar Alam Naqvi') # here I deliberately put incompatible pair of quaotes, 1 is double quote or 1 is single quote.
#           ^
# SyntaxError: unterminated string literal (detected at line 5)

# %% [markdown]
# 2. Default New Line

# %%
print("Shahwar")
print("Alam Naqvi")

# By the way print() is obviously a function
# By default, the print() function ends with a new line.
# Out:
# Shahwar
# Alam Naqvi

# %% [markdown]
# 3. Using `end` Parameter in Print

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")

# Printing on Same Line
# Out:
# Hello World! I will print on the same line.

# %%
print("I am Shahwar Alam Naqvi", end="******")
print("I am a Student at RACE, REVA")

# So end basically separates the two print sections and also keeps both prints in single line.
# Out:
# I am Shahwar Alam Naqvi******I am a Student at RACE, REVA

# %%
print("I am Shahwar Alam Naqvi", end=print())
print("I am a Student at RACE, REVA")

# Print actually returns None --> So end is None and we see the prints in separate line not in single line which end usually should do.
# Since end=None, meaning end parameter is None or nothing, so prints will print separately behaving s normal separate prints, no new line system here.
# Out:
# I am Shahwar Alam Naqvi
# I am a Student at RACE, REVA

# %%
print("I am Shahwar Alam Naqvi", end=None)
print("I am a Student at RACE, REVA")

# Directly putting None here.
# end=None, so no single line combining, only separate lines
# Out:
# I am Shahwar Alam Naqvi
# I am a Student at RACE, REVA

# %% [markdown]
# 4. Using `sep` parameter in print

# %%
# Simple separator example

print("Shahwar", "Alam", "Naqvi", sep="**")
# Out:
# Shahwar**Alam**Naqvi

# %%
# Using separator for multiline

print("Shahwar", "Alam", "Naqvi")
print()
print("Shahwar", "Alam", "Naqvi", sep="\n")
# Out:
# Shahwar Alam Naqvi
#
# Shahwar
# Alam
# Naqvi

# %% [markdown]
# 5. Printing Numbers and Text

# %%
print(121)
print(121, 4, 35)
print("abc", 12, 8.9)
# Out:
# 121
# 121 4 35
# abc 12 8.9

# %% [markdown]
# ## **6. Python Comments**

# %% [markdown]
# 1. Single Line Comment

# %%
# This is a Single line comment
# This is also a single line comment

# %% [markdown]
# 2. Multiline Comment

# %%
'''
This is a multi-line comment.
I understand it.
'''


"""
This is also a mutiline comment
I usually use it for documentation.
"""

#  Example:
def add(a, b):
    """This function adds two numbers."""
    return a + b

# %% [markdown]
# ## **7. Python Variables**

# %% [markdown]
# 1. Storing number in a variable

# %%
x=5
print(f"x: {x}")
# Out:
# x: 5

# %% [markdown]
# 2. Storing function in a variable

# %%
x=print()
print(f"x: {x}")
# Out:
# x: None

# %% [markdown]
# 3. Storing string in a variable

# %%
x_text = "Hello World"
print(f"x_text: {x_text}")
# Out:
# x_text: Hello World

# %% [markdown]
# 4. Vriable value displaying without print

# %%
x=5
y="Shahwar"
x, y
# Out:
# (5, 'Shahwar')

# %% [markdown]
# 5. Variable naming

# %%
# Allowed

myvar = "John" # all small
my_var = "John" # underscore in between
_my_var = "John" # underscore at beginning
myVar = "John" # camel case
MYVAR = "John" # all caps
myvar2 = "John" # can use number but not at beginning

# %% [markdown]
# 6. Variable names that will fail

# %%
2myvar = "John" # can't start with number
# Out:
#   File "/tmp/ipython-input-2718296599.py", line 1
#     2myvar = "John" # can't start with number
#     ^
# SyntaxError: invalid decimal literal

# %%
my-var = "John" # cannot use '-'
# Out:
#   File "/tmp/ipython-input-519631245.py", line 1
#     my-var = "John" # cannot use '-'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
my var = "John" # space cannot be allowed
# Out:
#   File "/tmp/ipython-input-3255261930.py", line 1
#     my var = "John" # space cannot be allowed
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 7. Cases - Pascal, Camel, Snake

# %%
myVariableName = "John" # Camel Case
MyVariableName = "John" # Pascal Case
my_variable_name = "John" # Snake Case

# %% [markdown]
# 8. Assignment : Assignment is Dynamic

# %%
x=45
y="I am Y"
x=y
x
# Out:
# 'I am Y'

# %% [markdown]
# 9. Assignment : Many values to Multiple variables

# %%
# 3 variable and 3 values

x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %% [markdown]
# 10. Assignment : 1 value to multiple variables

# %%
# 3 variables and 1 value

x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# 11. Unpack a Collection

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# 12. Output Variables

# %%
# take variable and print
x=55
print(x)
# Out:
# 55

# %%
# take 3 variables and print together (they are ',' separated)
x = "Python"
y = "is"
z = "awesome"
print(x, y, z) # by default a space while printing.

a=55
b=97
print(a, b) # by default a space while printing.
# Out:
# Python is awesome
# 55 97

# %%
x = "Python " #manual space at end
y = "is " #manual space at end
z = "awesome"
print(x + y + z) # with concatenation (using +) there is no default space, we have to manually give.

# Note : without them the result would be "Pythonisawesome".
# Out:
# Python is awesome

# %%
# Different types cannot be contatenated
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2005667415.py in <cell line: 0>()
#       2 x = 5
#       3 y = "John"
# ----> 4 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# 13. Case Sensitivity in variables

# %%
a="Shahwar"
A="Alam"
print(f"a: {a}")
print(f"A: {A}")
# Out:
# a: Shahwar
# A: Alam

# %% [markdown]
# ## **7. Global Variables**

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()

# This is just a simple scenario, where x is assigned outside and used (can be used in function as well)
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)

# In this scenario first outer x is assigned "awesome"
# The we come across a function, but we do not go inside since have not encountered a call to the function yet.
# As we move forward we see a call to function, now we have x now pointing to another value which is "fantastic"
# Point to note is there is no new x made, only the original x now pointing to new string value.
# The function also has a print for x, so we see fantastic printed
# Now as we move, we now encounter a fresh outside print (the last statement)
# Again x will now point to "awesome" as it initially did. When it pointed to "fantastic" it was local scope.
# Finally it prints "awesome"
# Out:
# Python is fantastic
# Python is awesome

# %%
x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)

# This is same code a before, only we add global keyword infront of local x inside the function
# What this essentially does is, it has now the power to override the outside x, x taking any affect inside the function will now be refleted outside the function as well.
# Out:
# Python is fantastic

# %%
# If you use the global keyword, the variable belongs to the global scope:
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)

# Thsi is another testing with no initial global declaration of x
# Out:
# Python is fantastic

# %% [markdown]
# ## **8. Types**

# %% [markdown]
# 1. Different Types

# %%
type(2)
type(2.24)
type("2.24")

# Last one will be shown (only)
# Out:
# str

# %%
#  To print all
print(type(2))
print(type(2.24))
print(type("2.24"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
x=5
print(type(x))

y="hello"
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# 2. Type Casting

# %%
x=23.45
x_str=str(23.45)
print(type(x))
print(type(x_str))

# What can be validly converted to a desired type we can do it as above
# Out:
# <class 'float'>
# <class 'str'>
